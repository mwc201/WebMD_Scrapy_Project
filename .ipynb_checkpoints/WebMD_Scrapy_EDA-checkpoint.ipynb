# %% [markdown]
# ## Exploratory Data Analysis: WebMD Reviews of Common Drugs
#
# ### Contents:
#
# • Read in scraped data <br>
# • Perform QA on data from scrape <br>
# • Exploratory Data Analysis <br>
# • Insights

# %%
import numpy as np
import pandas as pd

# %%
reviews = pd.read_csv('webmd_spider.csv')

# %%
reviews.sample(10)
# Out:
#                                                  comment  \
# 11735       still have all symptoms of being hypothyroid
# 14297  I JUST STARTED ABOUT ABOUT 2 WEEKS AGO, SO FAR...
# 18022  Switched from Cymbalta to this cause it made m...
# 24553  I have a question. \r\n\r\nI have been takin P...
# 38503  This is a great medication that gets a bad rap...
# 30433  I had to stop taking this drug because it made...
# 49541  I found this medication helpful when taken as ...
# 19602  after being on Namenda for about 4 weeks patie...
# 23301  was dissapointed,plus my doctor would only pre...
# 38635  since using Methadone for pain control I have ...
#
#                                           condition                   date  \
# 11735                           Underactive Thyroid  11/26/2011 2:32:19 PM
# 14297                      Chronic Trouble Sleeping   10/4/2008 9:03:43 AM
# 18022                                    Depression   6/2/2009 12:25:58 AM
# 24553                                    Overweight  6/16/2010 11:21:57 AM
# 38503                                          Pain    2/5/2009 8:08:26 PM
# 30433                                    Depression  10/6/2009 11:32:16 PM
# 49541                                          Pain   9/24/2013 3:50:13 PM
# 19602  Moderate to Severe Alzheimer's Type Dementia  5/11/2011 12:31:32 PM
# 23301                                    Overweight   3/2/2008 12:26:01 PM
# 38635                                          Pain  11/12/2009 3:30:21 PM
#
#                      drug  ease_of_use  effectiveness  \
# 11735      Synthroid oral            3              1
# 14297      trazodone oral            5              4
# 18022  Wellbutrin XL oral            4              2
# 24553    phentermine oral            4              4
# 38503      methadone oral            5              5
# 30433        Lexapro oral            4              1
# 49541  acetaminophen oral            4              4
# 19602        Namenda oral            5              1
# 23301    phentermine oral            5              3
# 38635      methadone oral            5              5
#
#                                                   review  satisfaction     sex
# 11735  Reviewer: 75 or over Female  on Treatment for ...             1  Female
# 14297  Reviewer: Beata31, 25-34 Female  on Treatment ...             4  Female
# 18022  Reviewer: 25-34 Female  on Treatment for 1 to ...             2  Female
# 24553  Reviewer: Mystic, 35-44 Female  on Treatment f...             4  Female
# 38503  Reviewer: husker30, 45-54 Female  on Treatment...             5  Female
# 30433  Reviewer: 45-54 Female  on Treatment for 10 ye...             1  Female
# 49541  Reviewer: dja, 45-54 Female  on Treatment for ...             1  Female
# 19602  Reviewer: dvlori, 75 or over Female  on Treatm...             1  Female
# 23301  Reviewer: lisa, 35-44 Female  on Treatment for...             2  Female
# 38635  Reviewer: linor1, 65-74 Female  on Treatment f...             5  Female

# %%
reviews.columns
# Out:
# Index(['comment', 'condition', 'date', 'drug', 'ease_of_use', 'effectiveness',
#        'review', 'satisfaction', 'sex'],
#       dtype='object')

# %% [markdown]
# How many reviews did we scrape?

# %%
len(reviews.drug)
# Out:
# 55262

# %% [markdown]
# How many unique drugs with reviews did we scrape?

# %%
reviews['drug'].nunique()
# Out:
# 95

# %% [markdown]
# How many reviews for each unique drug did we scrape?

# %%
reviews['drug'].value_counts()
# Out:
# lisinopril oral          3833
# acetaminophen oral       3821
# phentermine oral         2163
# Cymbalta oral            1936
# Lexapro oral             1919
#                          ...
# Valium oral                76
# Zofran oral                63
# Benadryl oral              55
# Emgality subcutaneous      54
# doxycycline oral           46
# Name: drug, Length: 95, dtype: int64

# %% [markdown]
# Check null values

# %%
np.sum(reviews.isnull())
# Out:
# comment          7
# condition        0
# date             0
# drug             0
# ease_of_use      0
# effectiveness    0
# review           0
# satisfaction     0
# sex              0
# dtype: int64

# %%
reviews.fillna('',inplace=True) # replace NA with ''

# %%
np.sum(reviews.isnull()) #recheck
# Out:
# comment          0
# condition        0
# date             0
# drug             0
# ease_of_use      0
# effectiveness    0
# review           0
# satisfaction     0
# sex              0
# dtype: int64

# %% [markdown]
# 7 null values

# %% [markdown]
# Summary stats of ratings

# %%
reviews.describe()
# Out:
#         ease_of_use  effectiveness  satisfaction
# count  55262.000000   55262.000000  55262.000000
# mean       4.134631       3.553961      3.203015
# std        1.237729       1.406416      1.576399
# min        1.000000       1.000000      1.000000
# 25%        4.000000       3.000000      1.000000
# 50%        5.000000       4.000000      3.000000
# 75%        5.000000       5.000000      5.000000
# max        5.000000       5.000000      5.000000

# %% [markdown]
# Note: 'ease_of_use', 'effectiveness', and 'satisfaction' fields are all 5-max ratings

# %% [markdown]
# #### Exploratory Data Analysis
# Closer look at content of the reviews, make some groupings, and analyze identified trends

# %%
reviews = reviews.rename(columns= {'date': 'date_time'}) #rename date to date_time

# %%
reviews.dtypes
# Out:
# comment          object
# condition        object
# date_time        object
# drug             object
# ease_of_use       int64
# effectiveness     int64
# review           object
# satisfaction      int64
# sex              object
# dtype: object

# %%
reviews['date_time'] = pd.to_datetime(reviews['date_time']) #change date_time from object to datetime

# %%
reviews.sample(10)
# Out:
#                                                  comment  \
# 7514   I have been on this. Med for years.  My gastro...
# 13688  I have taken this medication for 10+ yrs. It w...
# 7295   Its stopped my acid reflux but yesterday felt ...
# 13766  Started taking 50mg, 7 months ago due to 4 her...
# 39202  I just started this medicine today. I have onl...
# 9266   I am 59 & have RA, OA, Fibro & Degenerative Di...
# 21966                                         NO COMMENT
# 26608  Prednisone seems to be the only medication tha...
# 32482  Started on clonidine .02, 3 years ago, but it ...
# 34583                                         NO COMMENT
#
#                                                condition           date_time  \
# 7514                                     Irritable Colon 2014-02-11 19:13:23
# 13688                                               Pain 2011-06-29 15:09:38
# 7295   Condition in which Stomach Acid is Pushed Into... 2011-09-01 11:16:08
# 13766                                               Pain 2011-11-12 11:07:33
# 39202                                       Muscle Spasm 2016-10-17 21:17:42
# 9266   Disorder characterized by Stiff, Tender & Pain... 2009-09-29 14:57:57
# 21966                                               Pain 2008-10-10 22:11:54
# 26608                                             Asthma 2011-11-14 13:31:53
# 32482                                High Blood Pressure 2009-01-18 20:52:45
# 34583                                High Blood Pressure 2012-03-08 16:28:11
#
#                      drug  ease_of_use  effectiveness  \
# 7514     dicyclomine oral            3              4
# 13688       tramadol oral            5              5
# 7295        Dexilant oral            4              4
# 13766       tramadol oral            5              3
# 39202  methocarbamol oral            5              1
# 9266         Savella oral            5              4
# 21966       Percocet oral            5              4
# 26608     prednisone oral            4              5
# 32482     lisinopril oral            5              4
# 34583     lisinopril oral            4              1
#
#                                                   review  satisfaction     sex
# 7514   Reviewer: Joanie, 55-64 Female  on Treatment f...             3  Female
# 13688  Reviewer: 35-44 Female  on Treatment for 1 to ...             5  Female
# 7295   Reviewer: cindy, 45-54 Female  on Treatment fo...             2  Female
# 13766  Reviewer: girlinabottle50, 45-54 Female  (Pati...             4  Female
# 39202  Reviewer: kababy, 35-44 Female  on Treatment f...             1  Female
# 9266   Reviewer: albertwoman, 55-64 Female  on Treatm...             4  Female
# 21966  Reviewer: JacquiBlue, 35-44 Female  on Treatme...             4  Female
# 26608  Reviewer: mcneesmp, 45-54 Female  on Treatment...             4  Female
# 32482  Reviewer: 65-74 Male  on Treatment for 2 to le...             3    Male
# 34583  Reviewer: 35-44 Female  on Treatment for 6 mon...             1  Female

# %%
reviews.dtypes
# Out:
# comment                  object
# condition                object
# date_time        datetime64[ns]
# drug                     object
# ease_of_use               int64
# effectiveness             int64
# review                   object
# satisfaction              int64
# sex                      object
# dtype: object

# %%
import re 

def find_age(x):
    if re.findall('\d+-\d+', x):
        return re.findall('\d+-\d+',x)[0]
    else:
        return 'none'

# function to extract age in the review column

# %%
reviews['age'] = reviews.review.apply(find_age)

# %%
reviews.sample(10)
# Out:
#                                                  comment  \
# 46888                                         NO COMMENT
# 9905   I have SEVERE fibromyalgia and have tried more...
# 45731  My blood presure went down within first month....
# 40667  This is the 2nd time I've tried this medicatio...
# 28719  I had a constant choking feeling that started ...
# 28879                                         NO COMMENT
# 38419  I have been on Methadone for many years. I hav...
# 44842  I have had to take this medication several tim...
# 35213                                         NO COMMENT
# 48173                                         NO COMMENT
#
#                                                condition           date_time  \
# 46888                                               Pain 2008-12-28 14:35:08
# 9905   Disorder characterized by Stiff, Tender & Pain... 2013-02-06 12:00:36
# 45731                                High Blood Pressure 2009-09-09 02:13:24
# 40667                                              Cough 2008-03-27 09:38:03
# 28719                                Underactive Thyroid 2009-12-21 21:34:48
# 28879                                Underactive Thyroid 2011-03-18 10:48:00
# 38419                                               Pain 2008-05-06 18:12:18
# 44842                       Vaginosis caused by Bacteria 2013-10-30 17:04:45
# 35213                                High Blood Pressure 2014-05-21 12:05:32
# 48173                                               Pain 2010-05-26 13:00:19
#
#                            drug  ease_of_use  effectiveness  \
# 46888        acetaminophen oral            5              5
# 9905               Savella oral            4              1
# 45731  hydrochlorothiazide oral            5              5
# 40667          benzonatate oral            1              2
# 28719        levothyroxine oral            5              4
# 28879        levothyroxine oral            5              5
# 38419            methadone oral            5              4
# 44842               Flagyl oral            2              5
# 35213           lisinopril oral            5              5
# 48173        acetaminophen oral            4              4
#
#                                                   review  satisfaction  \
# 46888  Reviewer: chevygirl8773, 35-44 Female  on Trea...             5
# 9905      Reviewer: Travellinman, 55-64 Male  (Patient)              1
# 45731  Reviewer: rubberduck 10, 35-44 Female  on Trea...             3
# 40667  Reviewer: 25-34 Female  on Treatment for 1 to ...             1
# 28719  Reviewer: denlen1, 35-44 Female  on Treatment ...             4
# 28879  Reviewer: VSEITZ2756, 55-64 Female  on Treatme...             4
# 38419  Reviewer: packermama, 35-44 Female  on Treatme...             5
# 44842  Reviewer: nancyga13, 25-34 Female  on Treatmen...             3
# 35213  Reviewer: larry, 45-54 Male  on Treatment for ...             5
# 48173  Reviewer: baby, 35-44 Female  on Treatment for...             4
#
#           sex    age
# 46888  Female  35-44
# 9905     Male  55-64
# 45731  Female  35-44
# 40667  Female  25-34
# 28719  Female  35-44
# 28879  Female  55-64
# 38419  Female  35-44
# 44842  Female  25-34
# 35213    Male  45-54
# 48173  Female  35-44

# %%
age_gender = reviews[['sex', 'age']] 
#new df with only gender and age
age_gender = age_gender[~age_gender.age.str.contains('none')] 
#remove blank age
age_gender = age_gender[~age_gender.sex.str.contains('Patient')]
#remove gender that states patient which is unknown

# %%
from matplotlib import pyplot as plt

ind_lst = sorted(age_gender.groupby('age')['sex'].value_counts().unstack().dropna().index, key=lambda e: int(e.split("-")[0]))
ind_lst
# Out:
# ['0-2',
#  '3-6',
#  '7-12',
#  '13-18',
#  '19-24',
#  '25-34',
#  '35-44',
#  '45-54',
#  '55-64',
#  '65-74']

# %%
df = age_gender.groupby('age')['sex'].value_counts().unstack().dropna().loc[ind_lst]

# %%
df.plot(kind="barh", color=['mediumslateblue', 'tomato'], figsize=(10,7))
plt.title('User Demographics', fontsize=15)
plt.title('User Demographics', fontsize=15)
plt.xlabel('Number of Reviews')
plt.ylabel('Age')
plt.legend(loc='lower right')
plt.savefig("user_demographics.png",dpi=300,bbox_inches='tight')
plt.show()

# %%
age_gender.shape
# Out:
# (48028, 2)

# %% [markdown]
# <b>Question #1: How correlated are the ratings? (Effectiveness, Satisfaction, and Ease of Use)</b>

# %%
avg_ratings = reviews.groupby('drug').mean()
avg_ratings.sample(10)
# Out:
#                     ease_of_use  effectiveness  satisfaction
# drug
# prednisone oral        3.946667       4.008000      3.333333
# acetaminophen oral     4.269563       3.677833      3.570531
# Valium oral            4.250000       4.039474      4.026316
# Keflex oral            3.160920       2.885057      2.241379
# Plavix oral            4.035897       3.651282      3.187179
# amitriptyline oral     4.307947       3.536424      3.158940
# meloxicam oral         4.261745       3.449664      3.163311
# Vyvanse oral           4.168103       3.755172      3.376724
# Bystolic oral          3.972857       3.290000      2.677143
# lisinopril oral        3.998435       3.401513      2.720584

# %%
avg_ratings.shape
# Out:
# (95, 3)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corr_df = avg_ratings.corr()
sns.heatmap(corr_df, cmap = 'BuPu')
plt.yticks(rotation=0) 

#correlation heatmap of different types of ratings
#high corrleations for ease of use and satisfaction
#higher correlations for effectivness and satisfaction
# Out:
# (array([0.5, 1.5, 2.5]), <a list of 3 Text yticklabel objects>)

# %%
import nltk
drug_reviews = reviews[['drug', 'comment']]
drug_reviews
# Out:
#                 drug                                            comment
# 0       Abilify oral  DIAGNOSED WITH BP/DEPRESSION. ALSO TAKING LAMI...
# 1       Abilify oral  Caused feelings toward certain people to have ...
# 2       Abilify oral  the first week was hard. Lots of mania but it ...
# 3       Abilify oral  If this is the abilify tablet, I only take 7.5...
# 4       Abilify oral                                         NO COMMENT
# ...              ...                                                ...
# 55257  baclofen oral  Trying to come off low dose Xanax after 12 yea...
# 55258  baclofen oral  Prescribed baclofen when I had told the ER doc...
# 55259  baclofen oral  Used for back pain spasms but high hallucinati...
# 55260  baclofen oral  i was trying to recover from a bout of trigemi...
# 55261  baclofen oral                                         NO COMMENT
#
# [55262 rows x 2 columns]

# %%
valtrex_reviews = drug_reviews[drug_reviews['drug']=='Valtrex oral']
valtrex_reviews['comment'] = valtrex_reviews['comment'].str.lower() 
#change all characters into lowercase in comments

pd.options.mode.chained_assignment = None  # default='warn' #hide warning

# %%
valtrex_reviews['comment'] = valtrex_reviews['comment'].apply(lambda x: re.sub('valtrex',' ',x)) #remove and replace with space
valtrex_reviews['comment'] = valtrex_reviews['comment'].apply(lambda x: re.sub('\s+',' ',x))
valtrex_reviews['comment'] = valtrex_reviews['comment'].apply(lambda x: re.sub('[^\w\s]', '', x))

from nltk.corpus import stopwords
stop = stopwords.words('english')
stop.append(['doctor', 'Cure', 'drug', 'year', 'month', 'week', 'day', 'medication']) #remove words in list
valtrex_reviews['comment'] = valtrex_reviews['comment'].apply(lambda text: " ".join(word for word in text.split() if word not in stop))

valtrex_reviews['comment'].sample(10)
# Out:
# 15985    genital herpes almost 30 yrs im 57 began takin...
# 16031    hsv2 41 yrs get discovered primary care doc sa...
# 16164                     also call whatsapp 2348154724883
# 15922    would without greatly helped relieve worries h...
# 16106    hello everyone dr ogodo herbal medicine good r...
# 16196    excited share testimony 3 years ago diagnosed ...
# 16137    whatsapp number 16692213962 website wwwonihasp...
# 15942    48 hours im still lot tingling itching burning...
# 16159    cell whatsapp number 2347015927966 thank much ...
# 16177    call whatsapp 2347051705853 website osatoherba...
# Name: comment, dtype: object

# %%
from wordcloud import WordCloud
word_cloud = WordCloud(background_color="white", max_words=2000, width=800, height=400)
word_cloud.generate(' '.join(valtrex_reviews['comment']))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(8, 6))
plt.imshow(word_cloud, interpolation='bilinear')
plt.axis("off")
plt.suptitle('WordCloud of Valtrex Reviews', fontsize=16,x=0.5, y=0.0)
plt.savefig("WordCloud of Valtrex Reviews.png",dpi=300, bbox_inches='tight')
plt.show()

# %%
xanax_reviews = drug_reviews[drug_reviews['drug']=='Xanax oral']
xanax_reviews['comment'] = xanax_reviews['comment'].str.lower()
#change all characters into lowercase in comments

pd.options.mode.chained_assignment = None  #default='warn' 
#hide warning

# %%
xanax_reviews['comment'] = xanax_reviews['comment'].apply(lambda x: re.sub('xanax','',x))
xanax_reviews['comment'] = xanax_reviews['comment'].apply(lambda x: re.sub('\s+',' ',x))
xanax_reviews['comment'] = xanax_reviews['comment'].apply(lambda x: re.sub('[^\w\s]', '', x))

stop = stopwords.words('english')
stop.append(['doctor', 'Cure', 'drug', 'year', 'month', 'week', 'day', 'medication', 'taking', 'take']) 
#remove words in list
xanax_reviews['comment'] = xanax_reviews['comment'].apply(lambda text: " ".join(word for word in text.split() if word not in stop))

xanax_reviews['comment'].sample(10)
# Out:
# 18644    suffer agoraphobia take one go unfamiliar situ...
# 18892    drug one stopped panic attackssome drugs seeme...
# 18998    panic attacks like 16yrs taking 5mg twice day ...
# 18636    take 3 times day real hectic day keeps loosing...
# 18637    suffered severe panic attack husband committed...
# 19009    able function less anxiety mood calmer sleep b...
# 18941    med horrible almost took life body became depe...
# 18917         drug 8 years helped greatly works like ohter
# 19270                                              comment
# 19124    greatly helped isolated panic attacks anxiety ...
# Name: comment, dtype: object

# %%
from wordcloud import WordCloud
word_cloud2 = WordCloud(background_color="white", max_words=2000, width=800, height=400)
word_cloud2.generate(' '.join(xanax_reviews['comment']))

# %%
plt.figure(figsize=(8, 6))
plt.imshow(word_cloud2, interpolation='bilinear')
plt.axis("off")
plt.suptitle('WordCloud of Xanax Reviews', fontsize=16,x=0.5, y=0.0)
plt.savefig("WordCloud of Xanax Reviews.png",dpi=300, bbox_inches='tight')
plt.show()

# %%
condition_rank = reviews.condition.value_counts()
condition_rank
# Out:
# Pain                                                               8813
# Depression                                                         8053
# High Blood Pressure                                                6992
# Neuropathic Pain                                                   2936
# Chronic Trouble Sleeping                                           2722
# Attention Deficit Disorder with Hyperactivity                      2471
# Overweight                                                         2163
# Major Depressive Disorder                                          1936
# High Cholesterol                                                   1793
# Underactive Thyroid                                                1596
# Other                                                              1576
# Panic Disorder                                                     1269
# Joint Damage causing Pain and Loss of Function                     1172
# Anxious                                                            1172
# Chronic Pain                                                        919
# Bipolar Depression                                                  909
# Cough                                                               841
# Disorder characterized by Stiff, Tender & Painful Muscles           811
# Additional Medications to Treat Depression                          755
# Type 2 Diabetes Mellitus                                            751
# Muscle Spasm                                                        499
# Vaginosis caused by Bacteria                                        486
# Condition in which Stomach Acid is Pushed Into the Esophagus        429
# Treatment to Prevent a Blood Clot in a Vascular Stent               390
# Asthma                                                              375
# Migraine Prevention                                                 356
# Bacterial Urinary Tract Infection                                   322
# Inability to have an Erection                                       318
# Genital Herpes                                                      292
# Simple Partial Seizures                                             244
# Systemic Lupus Erythematosus                                        239
# Itching                                                             208
# Gout                                                                205
# Repeated Episodes of Anxiety                                        197
# Nausea and Vomiting                                                 176
# Irritable Colon                                                     155
# Skin Infection                                                      144
# Treatment to Prevent Blood Clots in Chronic Atrial Fibrillation     125
# Moderate to Severe Alzheimer's Type Dementia                        121
# Shingles                                                            112
# Blood Clot in Lung                                                   95
# Treatment to Prevent Heartburn                                       78
# Acne                                                                 46
# Name: condition, dtype: int64

# %%
reviews.drug.value_counts().head(10).plot.pie(figsize=(8,8),autopct='%0.01f%%')
plt.ylabel('')
plt.suptitle('Top 10 Drugs')
plt.savefig('Top 10 Drugs witht Most Reviews', dpi=2300, bbox_inches='tight')
plt.show()

# %%
condition_rank.head(10).plot.pie(figsize=(8,8),autopct='%0.01f%%')
plt.ylabel('')
plt.suptitle('Top 10 Conditions', fontsize=16)
plt.savefig("Top 10 Condition.png",dpi=300,bbox_inches='tight')
plt.show()

# %% [markdown]
# <b>Question #2: Which drugs are rated "Most Effective"? "Most Satisfactory"? "Easiest to Use"?</b>

# %%
group_drugs = reviews.groupby('drug')

# %%
group_drugs.size().sort_values(ascending=False)
# Out:
# drug
# lisinopril oral          3833
# acetaminophen oral       3821
# phentermine oral         2163
# Cymbalta oral            1936
# Lexapro oral             1919
#                          ...
# Valium oral                76
# Zofran oral                63
# Benadryl oral              55
# Emgality subcutaneous      54
# doxycycline oral           46
# Length: 95, dtype: int64

# %%
group_drugs.agg(['count', 'mean', 'std'])['effectiveness'].sort_values('mean',ascending=False).head(10)
# count, mean, std of effectiveness of top 10 drugs
# Out:
#                    count      mean       std
# drug
# Valtrex oral         292  4.654110  0.825007
# Xanax oral           716  4.493017  0.919840
# promethazine oral    113  4.353982  0.990313
# phentermine oral    2163  4.275081  1.053457
# Benadryl oral         55  4.272727  1.079344
# Zofran oral           63  4.269841  1.180573
# Adderall XR oral     513  4.142300  1.106278
# methadone oral       643  4.096423  1.090901
# Prilosec OTC oral     78  4.051282  1.288283
# clonazepam oral      553  4.045208  1.173276

# %%
plt.style.use('fivethirtyeight')
plt.hist(reviews['effectiveness'])
plt.title('Distribution of "Effectiveness" Ratings')
# Out:
# Text(0.5, 1.0, 'Distribution of "Effectiveness" Ratings')

# %%
plt.figure(figsize=(8, 4))
group_drugs['effectiveness'].mean().sort_values(ascending=False).head(10).plot.bar()
plt.title('10 Most Effective-Rated Medications')
plt.xticks(rotation=45)
plt.savefig("10 Most Effective Rated Meds by Avg.png",dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(8,4))
group_drugs['satisfaction'].mean().sort_values(ascending=False).head(10).plot.bar()
plt.title('10 Most Satisfactory-Rated Medications')
plt.xticks(rotation=45)
plt.savefig("10 Most Satisfactory Rated Meds.png",dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# Question 3: Dates
#  + Distribution of rating per date/year
#  + Distribution of review per year
#  + amount of review per year

# %%
from datetime import datetime as dt

reviews['date_time'] = pd.to_datetime(reviews['date_time']).dt.normalize()
# turn date time into just year

# %%
reviews.columns
# Out:
# Index(['comment', 'condition', 'date_time', 'drug', 'ease_of_use',
#        'effectiveness', 'review', 'satisfaction', 'sex', 'age'],
#       dtype='object')

# %%
#Rating per year
reviews.groupby('date_time')['effectiveness'].size()
# Out:
# date_time
# 2007-09-18    36
# 2007-09-19    37
# 2007-09-20    33
# 2007-09-21    32
# 2007-09-22    25
#               ..
# 2020-09-07     4
# 2020-09-09     3
# 2020-09-10     2
# 2020-09-11     2
# 2020-09-12     2
# Name: effectiveness, Length: 4254, dtype: int64

# %%
reviews.groupby('date_time')['effectiveness'].mean()
#average effectivness rating per day of a year
# Out:
# date_time
# 2007-09-18    3.527778
# 2007-09-19    3.864865
# 2007-09-20    3.878788
# 2007-09-21    4.218750
# 2007-09-22    3.840000
#                 ...
# 2020-09-07    4.500000
# 2020-09-09    3.666667
# 2020-09-10    3.000000
# 2020-09-11    3.000000
# 2020-09-12    5.000000
# Name: effectiveness, Length: 4254, dtype: float64

# %%
df = grouped_date.resample('1M').mean()

# %%
df.groupby('date_time')['effectiveness'].mean().plot(figsize=(22,12))
#average rating per year
plt.title("Average Effectiveness Rating Per Year", fontsize=28)
plt.ylabel("Effectiveness Rating")
plt.xlabel("Year")
plt.savefig("Avg Effectiveness Rating by Year.png",dpi=300, bbox_inches='tight')
plt.show()

# %%
reviews.groupby('date_time')['effectiveness'].size().resample('1M').mean()
# Out:
# date_time
# 2007-09-30    30.461538
# 2007-10-31    36.193548
# 2007-11-30    32.733333
# 2007-12-31    28.032258
# 2008-01-31    30.645161
#                 ...
# 2020-05-31     1.833333
# 2020-06-30     2.125000
# 2020-07-31     3.120000
# 2020-08-31     2.533333
# 2020-09-30     2.400000
# Freq: M, Name: effectiveness, Length: 157, dtype: float64

# %%
#Amount of Review per day of every year
reviews.groupby('date_time')['effectiveness'].size().resample('1W').mean().plot(figsize=(22,10))
plt.title("Amount of Reviews by Year", fontsize=28)
plt.ylabel("Number of Reviews")
plt.xlabel("Year")
plt.savefig("Amount of Reviews by Year.png",dpi=300, bbox_inches='tight')
plt.show()

# %%
### Using DatetimeIndex
grouped_date = reviews.groupby('date_time').agg({'effectiveness': np.mean, 'comment': np.size})

# %%
grouped_date.index
# Out:
# DatetimeIndex(['2007-09-18', '2007-09-19', '2007-09-20', '2007-09-21',
#                '2007-09-22', '2007-09-23', '2007-09-24', '2007-09-25',
#                '2007-09-26', '2007-09-27',
#                ...
#                '2020-09-02', '2020-09-03', '2020-09-04', '2020-09-05',
#                '2020-09-06', '2020-09-07', '2020-09-09', '2020-09-10',
#                '2020-09-11', '2020-09-12'],
#               dtype='datetime64[ns]', name='date_time', length=4254, freq=None)

# %%
grouped_date['date_time'] = grouped_date.index

# %%
grouped_date['date_time'] = pd.DatetimeIndex(grouped_date['date_time'])

# %%
grouped_date.dtypes
# Out:
# effectiveness           float64
# comment                   int64
# date_time        datetime64[ns]
# dtype: object

# %%
grouped_date = grouped_date.set_index('date_time')

# %%
# Select a Particular Date Range
grouped_date['2008'].plot()

# %%
# Amount of Reviews for 2008
grouped_date['2007']['comment'].plot(figsize=(15,10))
plt.title("Amount of Reviews for 2008")
plt.show()

# %%
# Amount of Reviews for 2008-2009
grouped_date['2007':'2009']['comment'].plot(figsize=(23,10))
plt.title("Amount of Reviews for 2007-2009")
plt.show()

# %%
#Distribution of Effectiveness Rating for Over Time
grouped_date['2008':'2009']['effectiveness'].plot(figsize=(17,10))
plt.title("Distribution of Effectiveness Rating Over Time")
plt.show()

# %%
#ratings were highest in June 2008

# %%
#Distribution of Effectiveness Rating for Over Time
grouped_date['2008':'2012']['effectiveness'].plot(figsize=(23,10))
plt.title("Distribution of Effectiveness Rating Over Time")
plt.show()

# %%
grouped_date['2008-04'].plot()

# %%
#Distribution of Effectiveness Rating for Over Two Months
grouped_date['2008-04':'2008-07']['effectiveness'].plot(figsize=(23,10))
plt.title("Distribution of Effectiveness Rating Over Time")
plt.show()
